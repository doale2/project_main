# %%
import os
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
# 분석 시간 폴더 경로
folder_path = '../res/'

# 폴더 목록 가져오기
folder_list = os.listdir(folder_path)

# %%
# 분석 시간 정보 추출 및 파일 선택
time_info = '20230604_222709'  # 분석 시간에 해당하는 정보를 입력하세요

# %%
file_name = f'analysis_result_{time_info}.csv'
file_path = os.path.join(folder_path, time_info, file_name)

# CSV 파일 불러오기
data = pd.read_csv(file_path)

data.head()
# Out:
#         Lot Wafer   Mask  TestSite                  Name             Date  \
# 0  HY202103   D07  LION1  DCM_LMZC  MZMCTE_LULAB_450_500  20190715_191703
# 1  HY202103   D07  LION1  DCM_LMZC  MZMCTE_LULAB_450_500  20190715_192309
# 2  HY202103   D07  LION1  DCM_LMZC  MZMCTE_LULAB_450_500  20190715_202341
# 3  HY202103   D07  LION1  DCM_LMZC  MZMCTE_LULAB_450_500  20190715_195307
# 4  HY202103   D07  LION1  DCM_LMZC  MZMCTE_LULAB_450_500  20190715_194108
#
#       Script ID  Script Version Script Owner Operator  ...  Column  ErrorFlag  \
# 0  process LMZC             0.1        D_노정완     ykim  ...      -1          0
# 1  process LMZC             0.1        D_노정완     ykim  ...      -3          0
# 2  process LMZC             0.1        D_노정완     ykim  ...       3          0
# 3  process LMZC             0.1        D_노정완     ykim  ...      -3          0
# 4  process LMZC             0.1        D_노정완     ykim  ...       0          0
#
#    Error description Analysis Wavelength  Rsq of Ref. spectrum (Nth)  \
# 0           No Error                1550                    0.998434
# 1           No Error                1550                    0.997227
# 2           No Error                1550                    0.997172
# 3           No Error                1550                    0.996162
# 4           No Error                1550                    0.998104
#
#    Max transmission of Ref. spec. (dB)  Rsq of IV  I at -1V [A]  I at 1V [A]  \
# 0                            -7.851665        1.0  2.603237e-08     0.006702
# 1                            -9.054541        1.0  4.890819e-08     0.006328
# 2                            -9.487260        1.0  4.591942e-08     0.006376
# 3                            -8.343672        1.0  5.465495e-08     0.006316
# 4                            -8.911875        1.0  4.814727e-08     0.006533
#
#    n_eff_0V
# 0  4.187352
# 1  4.210818
# 2  4.208677
# 3  4.181636
# 4  4.209112
#
# [5 rows x 21 columns]

# %%
sns.swarmplot(x = 'Wafer', y = 'ErrorFlag', data = data,
              hue='TestSite',
              hue_order=['DCM_LMZC', 'DCM_LMZO'],
              palette='viridis')
plt.title('ErrorFlag-swarm')
# Out:
# Text(0.5, 1.0, 'ErrorFlag-swarm')
