# %% [markdown]
# # Final Report
#
# *****
#
# ## Contents
# - [Introduction](#Introduction)
# - [Project information](#Project+information)
# - [Install and Run](#Install+and+Run)
# - [Description of the module file feature](#Description+of+the+module+file+feature)
# - [Example of analysis result](#Example+of+analysis+result)
# - [Conclusion](#Conclusion)
#
# *****
#
# # 1. Introduction
#
#    Team project of the Programming Engineering 2
#
#    _Department of Photonics and Nanoelectronics_
#    _In HANYANG University ERICA Campus_
#
#    **Team D**
#    - **Jungwan Noh**: npower220@hanyang.ac.kr
#    - **Kyusik Kim**: kimq6@hanyang.ac.kr
#    - **Yujeong Kim**: govldjsgovl@hanyang.ac.kr
#    - **Dohyeon Lee**: ehgus9806@hanyang.ac.kr
#
# # 2. Project information
#
# Wafer-scale data processing refers to a technology that efficiently manages and utilizes vast amounts of data of elements in
# each die at the wafer scale to improve the manufacturing process and enhance product quality.
# This requires the use of appropriate data formats and processing tools.
#
# So our team created a module that can efficiently extract  and analyze the XMLfiles provided by the customer,
# it also shows and saves information in graphs and csv files.
#
# Customers can select and analyze files, lots, wafers, column&row which they want.
#
#
# # 3. Install and Run

# %% [markdown]
# First, clone our project files in your repository
# >```{.python}
# git clone https://github.com/PE02teamD/project_main.git
# >```
#
# Install requirements to run our code
# >```{.python}
# pip install -r requirements.txt
# >```
#
# Run "run.py"
#
#   <img src="https://user-images.githubusercontent.com/93698770/241849695-c743f132-67c9-4671-956d-3e4eb0eaf088.png" height="300">
#
#   1. set data saving style. <br> you can select data save style _.png_ and _.csv_ both.
#
#   2. select files as _LOT ID, Wafer ID, Location, Date_. <br> when select nothing at list, select all automatically
#
#   3. show selected files. <br> after click _set scale_, show filename in this area.
#
#   4. UI settings. <br> change Appearance Mode _Light, Dark, System_ <br> change UI Scaling _80%, 90%, 100%, 110%, 120%_
#
#   5. set scale <br> save select files and show Number of Files.
#
#   6. progress bar <br> show progress ratio as the ratio which files are completed
#
#   7. analyze & exit <br> start analyze & exit button. <br> please check (1.)data saving style and (3.)selected XML files after analyze.
#   <br><img src="https://user-images.githubusercontent.com/119747175/243174250-1e3d9134-54a9-400e-bf1b-bb5474c8c8f9.gif" height="300">
#
#
#
# # 4. Description of the module file feature
# <i class="fa fa-folder" style="font-size: 24px; color: #FFBB00;"></i> .src
#
# - analyze_data.py: The code analyzes the XML file to visualize the data and store the results. You can choose different analysis methods for a given XML file, and generate graphs according to the selected analysis method and save the results. It also updates the progress bar indicating the progress of the analysis and performs error handling.
# <br/>
#
# - choose_analysis_scale.py: The code performs the function of navigating XML files in the "./dat" directory and generating a selection list based on information extracted from the file name. Deduplication is generated based on the information "lot", "wafer", "coordinate", and "date" extracted from the file name. Afterwards, the generated selection list is displayed in the GUI.
# <br/>
#
# - init_GUI.py: The code given serves to create and initialize the GUI using tkinter. The GUI has various components, including logos, check boxes, options menus, tab views, progress bars, list boxes, and buttons. This code sets the layout and initial values of these elements. Also, call the choose_analysis_scale function to generate a selection list and display it in the GUI.
# <br/>
#
# - iv_fitting.py: The given code performs the function of fitting the voltage-current curve for the given IV data. The code first divides the data based on the threshold voltage and applies different fitting methods to the previous and subsequent data. Previous data use polynomial approximation, and subsequent data perform fitting using the model function defined. Finally, the two fitting results are combined into one list and returned.
# <br/>
#
# - iv_graph.py: The code parses IV data from XML files and uses matplotlib to visualize the data. In addition, IV fitting is performed on the IV data to draw the optimal curve and save the graph as a PNG file.
# <br/>
#
# - main.py: The code initializes the GUI application and handles events that change the appearance mode and sizing based on user input. It also includes methods that perform data analysis functions, store and display results, and methods that terminate applications.
# <br/>
#
# - save_choosed_data.py: Finds the file path based on the index you select and saves the path of the selected files. The function displays a list of selected files in a text box.
# <br/>
#
# - save_csv.py: Extracts the required data from the XML file and returns it to the list. Extract data from the XML file you extract, and utilize the extracted data to create a DataFrame and save it as a CSV file.
# <br/>
#
# - setting_subplots.py: Creates a 3x3 subplot and returns the created subplot. Each subplot sets a title, label, tick, etc. according to the given format Process detailed settings for the subplot. For each subplot, set the title, label, tick size, and so on, and add legends and grids.
# <br/>
#
# - ts_fitting.py: The code processes optical transmission data to fit the optimal model and generate graphs. Key features include conversion between dBm and linear values, n_eff extraction from optical transmissions, and fitting a voltage-consideration model.
# <br/>
#
# - ts_graph.py: This code parses data from XML files to create optical transmission graphs and provides the ability to fit the optimal model. It also has the ability to calculate R² values by comparing measured data with optimal models, and to perform first-order approximation by extracting peaks.
#
# <i class="fa fa-folder" style="font-size: 24px; color: #FFBB00;"></i> dat
#
# Users can perform wafer scale data processing by placing XML files in the "dat" folder.
#
# <i class="fa fa-folder" style="font-size: 24px; color: #FFBB00;"></i> doc
#
# There is a Jupyter Notebook file in the "doc" folder. It represents a folder dedicated to documentation, explanations, or notes related to the project. Jupyter Notebook is an environment that combines interactive code and documents used for tasks such as data analysis, visualization, and modeling.
#
# <i class="fa fa-folder" style="font-size: 24px; color: #FFBB00;"></i> ppt
#
# There is a .pptx file or presentation materials in ppt folder.
#
# <i class="fa fa-folder" style="font-size: 24px; color: #FFBB00;"></i> res
#
# The analyzed data is stored in the "res" folder within a folder named with the analysis time.
#
# <i class="fa fa-folder" style="font-size: 24px; color: #FFBB00;"></i> venv
#
# - .gitignore: The .gitignore file is used to specify files and directories that should not be tracked by Git.It is used to exclude files related to the development environment or containing sensitive information from being committed to the repository.
# <br/>
# - README.md: The README file provides an introduction, usage instructions, installation methods, license information, project structure, and other details about the project.
# <br/>
# - requirements.txt: The requirements.txt file lists the dependencies of a Python project, specifying external packages needed for the project.It is used to install the required packages in a virtual environment. The file lists each package with its name and version information on separate lines.
# <br/>
# - run.py: The run.py file is responsible for starting the program, performing necessary configurations and initializations, and executing the main functionality of the project.
#
#
#
# # 5. Example of analysis result
# Customers can extract and analyze XML files provided by the customer using our module, which efficiently handles the data processing. The program also presents the information in the form of graphs and saves it in both **CSV file** and **PNG file** formats.
#
# The CSV files contains comprehensive information, including details such as lot, wafer, mask, testsite, name, date, script ID,
# script version, script owner, operator, row, column, error flag, error description, analysis wavelength,
# Rsq of the Nth reference spectrum, maximum transmission of the reference spectrum (in dB), Rsq of the IV curve,
# and current values at -1V and 1V.
#
# The PNG files include various graphs, such as the measured transmission spectra, flat transmission spectra, IV analysis,
# flat flat transmission, n-V curve, and enlarged flat flat transmission spectra (in dBm).
# These graphs provide visual representations of the component's performance and characteristics.
#
# ><p style="font-size:20px">Information contained in CSV file</p>
#
# |<p style="font-size:20px">  </p>|||||
# |:---:|:---:|:---:|:---:|:---:|
# |Lot|Wafer|Mask|TestSite|Name|
# |Date|Script ID|Script Version|Script Owner|Operator|
# |Row|Column|ErrorFlag|Error description|Analysis Wavelength|
# |Rsq of Ref. spectrum(Nth)|Max transmission of Ref. spec. (dB)|Rsq of IV|I at -1V[A]|I at 1V [A]|
#
#
# ><p style="font-size:20px">example of a CSV file opened in Excel</p>
#
# ![csv file image](https://github.com/Yujeongkiim/week2/assets/127360881/45fac22a-395f-4403-8f8a-341d344ac2c3)
#
# ><p style="font-size:20px">Graphs contained in PNG file</p>
#
# |<p style="font-size:20px">  </p>|||
# |:---:|:---:|:---:|
# |Transmission spectra - as measured|Transmission spectra - as measured|Flat Transmission spectra - as measured|
# |IV - analysis|Flat Flat Transmission|Flat Flat Transmission enlarged|
# |n_V_curve|Flat Flat Transmission enlarged dBm| |
#
# ><p style="font-size:20px">example of a PNG file</p>
#
# ![csv file image](https://github.com/Yujeongkiim/week2/assets/127360881/927d371b-a643-4b31-b66a-e863e40a7a8d)
#
# # 6. Conclusion
#
#  In conclusion, our project has developed an automated wafer-scale data processing program, empowering users with easier and more efficient analysis of device performance through the provided CSV files and graphical representations in PNG format. This program accelerates data-driven decision-making and optimization in semiconductor device development.
